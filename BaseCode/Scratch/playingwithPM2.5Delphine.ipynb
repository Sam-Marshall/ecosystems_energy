# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
PM2 = pd.read_csv('../Data/clean_Mean population exposure to PM2.5.csv')

# %%
PM2.head()
# Out:
#    True   Country                           Variable  Year  \
# 0  3528  Malaysia  Mean population exposure to PM2.5  2000
# 1  3529  Malaysia  Mean population exposure to PM2.5  2001
# 2  3530  Malaysia  Mean population exposure to PM2.5  2002
# 3  3531  Malaysia  Mean population exposure to PM2.5  2003
# 4  3532  Malaysia  Mean population exposure to PM2.5  2004
#
#                          Unit     Value
# 0  Micrograms per cubic metre  18.96619
# 1  Micrograms per cubic metre  19.36809
# 2  Micrograms per cubic metre  20.69490
# 3  Micrograms per cubic metre  18.93037
# 4  Micrograms per cubic metre  23.15562

# %%
PM2.set_index('Year', inplace=True)
PM2.groupby('Country')['Value'].plot(legend=True)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
#Median over all the countries
PM2.reset_index(inplace=True)
sns.lineplot(x=PM2['Year'], y=PM2['Value'], data=PM2)
plt.show() #increase :(

# %%
sns.violinplot(x=PM2['Country'], y=PM2['Value'], data=PM2)
plt.xticks(rotation=90)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#USA
PM2.set_index('Year', inplace=True)
PM2[PM2['Country'] == 'United States']['Value'].plot()
plt.ylim(0,20)
plt.title("PM2.5 exposure in USA") #good job
# Out:
# Text(0.5,1,'PM2.5 exposure in USA')

# %%
#France
#PM2.set_index('Year', inplace=True)
PM2[PM2['Country'] == 'France']['Value'].plot()
plt.ylim(0,20)
plt.title("PM2.5 exposure in France")
# Out:
# Text(0.5,1,'PM2.5 exposure in France')

# %%
'''Other dataset'''

# %%
#lossofland
LOL = pd.read_csv('../Data/clean_Lossofland.csv')

# %%
LOL.head()
# Out:
#    True       Country                                           Variable  \
# 0  6200      Honduras  Loss of natural and semi-natural vegetated lan...
# 1  6201      Honduras  Loss of natural and semi-natural vegetated lan...
# 2  6204  Turkmenistan  Loss of natural and semi-natural vegetated lan...
# 3  6205  Turkmenistan  Loss of natural and semi-natural vegetated lan...
# 4  6223         Japan  Loss of natural and semi-natural vegetated lan...
#
#    Year        Unit    Value
# 0  2004  Percentage  3.54461
# 1  2015  Percentage  4.72344
# 2  2004  Percentage  1.41743
# 3  2015  Percentage  1.81357
# 4  2004  Percentage  3.66427

# %%
LOL.set_index('Year', inplace=True)
LOL.groupby('Country')['Value'].plot(legend=True)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
#USA
#PM2.set_index('Year', inplace=True)
LOL[LOL['Country'] == 'United States']['Value'].plot()
plt.ylim(0,5)
plt.title("LOL in USA") #good job
# Out:
# Text(0.5,1,'LOL in USA')

# %%
#France
#PM2.set_index('Year', inplace=True)
LOL[LOL['Country'] == 'France']['Value'].plot()
plt.ylim(0,5)
plt.title("LOL in France")
# Out:
# Text(0.5,1,'LOL in France')

# %%
'''Other dataset'''

# %%
RD = pd.read_csv('../Data/clean_R&Dbudget.csv')

# %%
RD.head()
# Out:
#    True    Country                                           Variable  Year  \
# 0     0  Australia  Environmentally related government R&D budget,...  1990
# 1     1  Australia  Environmentally related government R&D budget,...  1995
# 2     2  Australia  Environmentally related government R&D budget,...  2000
# 3     3  Australia  Environmentally related government R&D budget,...  2001
# 4     4  Australia  Environmentally related government R&D budget,...  2002
#
#          Unit     Value
# 0  Percentage  3.114999
# 1  Percentage  1.194281
# 2  Percentage  2.950041
# 3  Percentage  2.938141
# 4  Percentage  2.903972

# %%
#USA
#RD.set_index('Year', inplace=True)
RD[RD['Country'] == 'United States']['Value'].plot()
plt.ylim(0,5)
plt.title("RD in USA") #bad job
# Out:
# Text(0.5,1,'RD in USA')

# %%
#France
#RD.set_index('Year', inplace=True)
RD[RD['Country'] == 'France']['Value'].plot()
plt.ylim(0,5)
plt.title("RD in France") #good job
# Out:
# Text(0.5,1,'RD in France')

# %%
'''Other dataset'''

# %%
Total = pd.read_csv('../Data/clean_TotalGazEmission.csv')

# %%
Total.head()
# Out:
#    True    Country                           Variable  Year  \
# 0     0  Australia  Total  emissions excluding LULUCF  1990
# 1     1  Australia  Total  emissions excluding LULUCF  1991
# 2     2  Australia  Total  emissions excluding LULUCF  1992
# 3     3  Australia  Total  emissions excluding LULUCF  1993
# 4     4  Australia  Total  emissions excluding LULUCF  1994
#
#                        Unit       Value
# 0  Tonnes of CO2 equivalent  419843.155
# 1  Tonnes of CO2 equivalent  420927.191
# 2  Tonnes of CO2 equivalent  425820.883
# 3  Tonnes of CO2 equivalent  426128.333
# 4  Tonnes of CO2 equivalent  426074.577

# %%
#USA
#Total.set_index('Year', inplace=True)
Total[Total['Country'] == 'United States']['Value'].plot()
plt.title("Total in USA") # ????
# Out:
# Text(0.5,1,'Total in USA')

# %%
#France
#Total.set_index('Year', inplace=True)
Total[Total['Country'] == 'France']['Value'].plot()
plt.title("Total in France") # ????
# Out:
# Text(0.5,1,'Total in France')
