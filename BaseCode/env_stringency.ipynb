# %%
import pandas as pd

# %%
stringency_file = "../Data/original_env_stringency.csv"
stringency_csv = pd.read_csv(stringency_file)
stringency_df = pd.DataFrame(stringency_csv)

list(stringency_df.columns.values)
stringency_df['PowerCode'].value_counts()
# Out:
# Units    17650
# Name: PowerCode, dtype: int64

# %%
stringency_df = stringency_df[['COU', 'Country', 'Variable', 'Year', 'Value',]]

# %%
stringency_df
# Out:
#        COU Country                          Variable  Year  Value
# 0      GRC  Greece  Sulphur content limit for diesel  1990   1.00
# 1      GRC  Greece  Sulphur content limit for diesel  1991   1.00
# 2      GRC  Greece  Sulphur content limit for diesel  1992   1.00
# 3      GRC  Greece  Sulphur content limit for diesel  1993   2.00
# 4      GRC  Greece  Sulphur content limit for diesel  1994   2.00
# 5      GRC  Greece  Sulphur content limit for diesel  1995   2.00
# 6      GRC  Greece  Sulphur content limit for diesel  1996   2.00
# 7      GRC  Greece  Sulphur content limit for diesel  1997   2.00
# 8      GRC  Greece  Sulphur content limit for diesel  1998   2.00
# 9      GRC  Greece  Sulphur content limit for diesel  1999   2.00
# 10     GRC  Greece  Sulphur content limit for diesel  2000   4.00
# 11     GRC  Greece  Sulphur content limit for diesel  2001   4.00
# 12     GRC  Greece  Sulphur content limit for diesel  2002   4.00
# ...

# %%
stringency_df.to_csv("../Data/")
