# %%
import pandas as pd

# %%
RandD = pd.read_csv('../Data/Green_economic_opportunities.csv')

# %%
RandD.head()
# Out:
#    COU    Country           VAR  \
# 0  AUS  Australia  ENVRD_GBAORD
# 1  AUS  Australia  ENVRD_GBAORD
# 2  AUS  Australia  ENVRD_GBAORD
# 3  AUS  Australia  ENVRD_GBAORD
# 4  AUS  Australia  ENVRD_GBAORD
#
#                                             Variable   YEA  Year Unit Code  \
# 0  Environmentally related government R&D budget,...  1990  1990        PC
# 1  Environmentally related government R&D budget,...  1995  1995        PC
# 2  Environmentally related government R&D budget,...  2000  2000        PC
# 3  Environmentally related government R&D budget,...  2001  2001        PC
# 4  Environmentally related government R&D budget,...  2002  2002        PC
#
#          Unit  PowerCode Code PowerCode  Reference Period Code  \
# 0  Percentage               0     Units                    NaN
# 1  Percentage               0     Units                    NaN
# 2  Percentage               0     Units                    NaN
# ...

# %%
del RandD['COU']
del RandD['VAR']
del RandD['YEA']
del RandD['Unit Code']
del RandD['PowerCode Code']
del RandD['Reference Period Code']
del RandD['Reference Period']
del RandD['Flag Codes']
del RandD['Flags']
del RandD['PowerCode']

# %%
RandD['Variable'].value_counts()
# Out:
# Development of environment-related technologies, % all technologies           2210
# Development of environment-related technologies, % inventions worldwide       2210
# Relative advantage in environment-related technology                          2210
# Development of environment-related technologies, inventions per capita        2210
# Environmentally related taxes, % GDP                                           920
# Energy related tax revenue, % total environmental tax revenue                  919
# Environmentally related taxes, % total tax revenue                             914
# Road transport-related tax revenue, % total environmental tax revenue          913
# Fossil fuel consumption support, % total tax revenue                           811
# Total fossil fuel support, % of total tax revenue                              811
# Petroleum support, % total fossil fuel support                                 744
# ...

# %%
#Environmentally related government R&D budget is the only one we want?

for i, g in RandD.groupby('Variable'):
    if i == "Environmentally related government R&D budget, % total government R&D":   
        g.to_csv('../Data/clean_R&Dbudget.csv', header=True, index_label=True)
